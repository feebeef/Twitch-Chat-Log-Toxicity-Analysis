# %%
labels = ["Direct Harassment", "Hate Speech","Sexual Harassment","Trolling", "Others", "Toxic"]

batch_files = ['usanews.csv', 'foxnews0.csv', 'foxnews1.csv', 'foxnews2.csv', 'foxnews3.csv', 
                'nogla0.csv','pew0.csv', 'rae0_0.csv', 
                 'rae0_1.csv', 'terror0_0.csv', 'terror0_1.csv']

vid_files = ["foxnews_FULL.csv", "rae_FULL.csv",  "terror_FULL.csv",
             "usanews.csv" , "pew0.csv", "nogla0.csv", "drdisrespect_FULL.csv"]
genre_files = ["gaming_channels_GENRE.csv", "news_channel_GENRE.csv" ]

files = []
files.extend(vid_files)
files.extend(genre_files)
print(files)
# Out:
# ['foxnews_FULL.csv', 'rae_FULL.csv', 'terror_FULL.csv', 'usanews.csv', 'pew0.csv', 'nogla0.csv', 'drdisrespect_FULL.csv', 'gaming_channels_GENRE.csv', 'news_channel_GENRE.csv']

# %%
import pandas as pd
import numpy as np
import json
import random

# %%
src_folder = "RESULTS/"
for file in genre_files:
    df = pd.read_csv(src_folder+file, index_col = 0)
    display(df)
# Out:
#     Topic Direct Harassment Hate Speech Sexual Harassment Trolling  Others  \
# 0       0            0.0198     -0.0149                 -        -       -
# 1      11            0.0227      0.1448            0.0164   0.0222       -
# 2      13            0.0296           -            0.0163        -       -
# 3      15            0.0356           -                 -        -       -
# 4      17                 -           -                 -        -       -
# 5      20              0.03     -0.0138                 -        -       -
# 6      27                 -           -                 -        -       -
# 7      28            0.0266           -                 -   0.0276       -
# 8      29            0.0197     -0.0142                 -   0.0111       -
# 9      36            0.0141     -0.0132                 -        -       -
# 10     39              0.02           -            0.0112        -       -
# 11      4            0.0154     -0.0144                 -        -       -
# 12     44            0.0307     -0.0115                 -   0.0305       -
# 13     45            0.0122     -0.0173                 -        -       -
# 14     46            0.0284           -            0.0189        -       -
# 15     50            0.0223      0.0154            0.0153   0.0337       -
# 16     54            0.0206     -0.0148            0.0161   0.0116       -
# 17     55                 -           -                 -        -       -
# 18     58            0.0131     -0.0211                 -        -       -
# 19     59            0.0225      0.0297            0.0168   0.0216       -
# 20     62            0.0345     -0.0113                 -        -       -
# 21     64            0.0131           -                 -        -       -
# 22     68            0.0161     -0.0135                 -        -       -
# 23     69                 -       -0.02                 -        -       -
# 24     71            0.0164           -                 -        -  0.0225
# 25     74                 -           -                 -        -       -
# 26     75            0.0161           -                 -        -       -
# 27     82            0.0335     -0.0112            0.0186        -       -
# 28     83            0.0238           -                 -   0.0167       -
# 29     84                 -     -0.0166             0.011        -       -
# 30      9             0.021           -                 -        -       -
# 31     94            0.0303     -0.0122            0.0147   0.0118       -
# 32     96            0.0228           -                 -   0.0145       -
#
#      Toxic                              Topic Top 10 Keywords
# 0   0.0141  ['lol', 'arcadum', 'lily', 'toast', 'hair', 'e...
# 1   0.0380  ['blm', 'joke', 'racist', 'death', 'terrorist'...
# 2   0.0167  ['like', 'yayayayayaya', '2x', 'forget', 'soun...
# 3   0.0240  ['chat', 'toxic', 'read', 'look', 'close', 'an...
# 4   0.0280  ['oh', 'uh', 'god', 'boy', 'yeah', 'shit', 'no...
# 5   0.0219  ['brian', 'night', 'look', 'keep', 'stop', 'da...
# 6   0.0117  ['ad', 'blocker', 'twitch', 'mobile', 'premium...
# 7   0.0178  ['stream', 'forget', 'enjoy', 'snipe', 'start'...
# 8   0.0171  ['play', 'jacksepticeye', 'corpse', 'want', 's...
# 9   0.0136  ['gg', 'yay', 'win', 'lmfao', 'pete', 'lmaoooo...
# 10  0.0148  ['yo', 'yumi', 'live', 'wtf', 'hair', 'tom', '...
# 11  0.0111  ['lmao', 'arcadum', 'edgar', 'poor', 'hair', '...
# 12  0.0246  ['game', 'fun', 'start', 'ruin', 'mod', 'light...
# 13  0.0142  ['code', 'use', 'moo', 'among', 'cover', 'want...
# 14  0.0262  ['bruh', 'mod', 'tf', 'moment', 'momento', 'fa...
# 15  0.0190  ['say', 'people', 'death', 'would', 'tom', 'vo...
# 16  0.0119  ['felix', 'quiet', 'ur', 'scare', 'poor', 'gho...
# 17  0.0134  ['think', 'brodie', 'noah', 'yumi', 'still', '...
# 18  0.0135  ['turn', 'light', 'volume', 'mic', 'need', 'ur...
# 19  0.0177  ['matter', 'black', 'life', 'op', 'blue', 'liv...
# 20  0.0215  ['imposter', '3rd', 'third', 'yumi', 'terroris...
# 21  0.0145  ['sup', 'man', 'pewdiefloorgang2', 'boy', 'bry...
# 22  0.0121  ['ok', 'funny', 'yea', 'jesus', 'username', 'a...
# 23  0.0114  ['join', 'work', 'try', 'want', 'com', 'please...
# 24  0.0121  ['kill', 'win', 'want', 'try', 'mcnasty', 'sta...
# 25  0.0135  ['ya', 'tell', 'win', 'll', 'yeah', 'cut', 'to...
# 26  0.0246  ['loud', 'af', 'asf', 'really', 'sean', 'littl...
# 27  0.0138  ['watch', 'live', 'fun', 'since', 'work', 'vid...
# 28  0.0137  ['bo2', 'cod', 'great', '2020', 'hype', 'ever'...
# 29  0.0157  ['big', 'brain', 'oof', 'fan', 'pete', 'small'...
# 30  0.0137  ['jack', 'quiet', 'voice', 'de', 'echo', 'incr...
# 31  0.0228  ['talk', 'wtf', 'people', 'politic', 'among', ...
# 32  0.0135  ['damn', 'son', 'really', 'cam', 'face', 'pewd...
#     Topic Direct Harassment Hate Speech Sexual Harassment Trolling  Others  \
# 0       1                 -           -                 -   0.0201       -
# 1      11            0.0456      0.0279                 -   0.0437  0.0245
# 2      12                 -       0.017                 -   0.0284       -
# 3      13            0.0266       0.049                 -   0.0547       -
# 4      14           -0.0139           -                 -        -       -
# ..    ...               ...         ...               ...      ...     ...
# 60     95            0.0575        0.06                 -   0.0619  0.0331
# 61     96            0.0352      0.0326                 -   0.0528  0.0268
# 62     97            0.0222      0.0284                 -   0.0558  0.0289
# 63     98            0.0226           -             0.019   0.0335       -
# 64     99            0.0206      0.0261                 -   0.0326       -
#
#      Toxic                              Topic Top 10 Keywords
# 0   0.0139  ['ðÿ', 'ƒðÿ', 'šðÿ', 'žðÿ', '¼ðÿ', 'œðÿ', '½ðÿ...
# 1   0.0480  ['go', 'home', 'miss', 'hell', 'john', 'away',...
# 2   0.0203  ['maga', 'forever', 'kag', 'motown', 'tear', '...
# 3   0.0252  ['win', 'must', 'winning', 'hope', 'big', 'cru...
# 4  -0.0242  ['president', 'vice', 'mr', 'amazing', 'never'...
# ..     ...                                                ...
# 60  0.0560  ['pelosi', 'nancy', 'fire', 'retire', 'jail', ...
# 61  0.0352  ['way', 'already', 'ticket', 'republican', 'li...
# 62  0.0271  ['free', 'kyle', 'know', 'truth', 'election', ...
# 63  0.0180  ['_rsbnusa', '_rsbntrump', 'rsbnusa', '_rsbnka...
# 64  0.0192  ['uk', '_rsbnusa2', 'election', 'watch', 'rsbn...
#
# [65 rows x 8 columns]
