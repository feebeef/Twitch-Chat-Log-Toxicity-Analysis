# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from nltk import pos_tag
# %matplotlib inline

# %% [markdown]
# ### Custom Function

# %%
def count_tags(title_with_tags):
    tag_count = {}
    for word, tag in title_with_tags:
        if tag in tag_count:
            tag_count[tag] += 1
        else:
            tag_count[tag] = 1
    return(tag_count)

# %%
df = pd.read_csv(r"D:\Programs\Jupyter Notebooks\ThesisScripts-master\Annotations\usanews0\usanews.csv") #CHANGE VALUE PER FILE
df.head()
# Out:
#    Unnamed: 0                                            message  \
# 0           0                          DEMOCRATS ARE TERRORISTS!
# 1           1  Let's be honest, they aren't voting for Biden,...
# 2           2                 Where would we be if not for RSBN?
# 3           3    THEY WON'T BE HAPPY WHEN THEY ARE REGULATED 😛😛😥
# 4           4                                         TRUMP 2020
#
#    Direct Harassment  Hate Speech  Sexual Harassment  Trolling  Others  Toxic
# 0                NaN          1.0                NaN       NaN     NaN    NaN
# 1                NaN          NaN                NaN       NaN     NaN    NaN
# 2                NaN          NaN                NaN       NaN     NaN    NaN
# 3                NaN          1.0                NaN       NaN     NaN    NaN
# 4                NaN          NaN                NaN       NaN     NaN    NaN

# %%
df['POS'] = df['message'].str.split().map(pos_tag)
df.head(10)
# Out:
#    Unnamed: 0                                            message  \
# 0           0                          DEMOCRATS ARE TERRORISTS!
# 1           1  Let's be honest, they aren't voting for Biden,...
# 2           2                 Where would we be if not for RSBN?
# 3           3    THEY WON'T BE HAPPY WHEN THEY ARE REGULATED 😛😛😥
# 4           4                                         TRUMP 2020
# 5           5                                     SALT MUST FLOW
# 6           6  Corn Pop say I pity da fool who don't eat Mr T...
# 7           7  RSBN IS THE GREATEST GIFT FOR THIS CLIMACTIC M...
# 8           8                    TRUMP 95% IN CALIFORNIA🤩🤩🤩🤩🤩🤩🤩🤩
# 9           9                            💙 BIDE‎N FO‍R RACISM! 💙
#
#    Direct Harassment  Hate Speech  Sexual Harassment  Trolling  Others  Toxic  \
# 0                NaN          1.0                NaN       NaN     NaN    NaN
# 1                NaN          NaN                NaN       NaN     NaN    NaN
# 2                NaN          NaN                NaN       NaN     NaN    NaN
# 3                NaN          1.0                NaN       NaN     NaN    NaN
# 4                NaN          NaN                NaN       NaN     NaN    NaN
# 5                NaN          NaN                NaN       NaN     NaN    NaN
# 6                NaN          NaN                NaN       NaN     NaN    NaN
# 7                NaN          NaN                NaN       NaN     NaN    NaN
# 8                NaN          NaN                NaN       NaN     NaN    NaN
# 9                1.0          1.0                NaN       NaN     NaN    1.0
#
#                                                  POS
# 0  [(DEMOCRATS, NNPS), (ARE, VBP), (TERRORISTS!, ...
# 1  [(Let's, NNP), (be, VB), (honest,, VBN), (they...
# 2  [(Where, WRB), (would, MD), (we, PRP), (be, VB...
# 3  [(THEY, NNP), (WON'T, NNP), (BE, NNP), (HAPPY,...
# 4                          [(TRUMP, NN), (2020, CD)]
# 5            [(SALT, NNP), (MUST, NNP), (FLOW, NNP)]
# 6  [(Corn, JJ), (Pop, NNP), (say, VBP), (I, PRP),...
# 7  [(RSBN, NNP), (IS, VBZ), (THE, NNP), (GREATEST...
# 8  [(TRUMP, $), (95%, CD), (IN, NNP), (CALIFORNIA...
# 9  [(💙, JJ), (BIDE‎N, NNP), (FO‍R, NNP), (RACISM!...

# %%
df['tagCounts'] = df['POS'].map(count_tags)
df.head(10)
# Out:
#    Unnamed: 0                                            message  \
# 0           0                          DEMOCRATS ARE TERRORISTS!
# 1           1  Let's be honest, they aren't voting for Biden,...
# 2           2                 Where would we be if not for RSBN?
# 3           3    THEY WON'T BE HAPPY WHEN THEY ARE REGULATED 😛😛😥
# 4           4                                         TRUMP 2020
# 5           5                                     SALT MUST FLOW
# 6           6  Corn Pop say I pity da fool who don't eat Mr T...
# 7           7  RSBN IS THE GREATEST GIFT FOR THIS CLIMACTIC M...
# 8           8                    TRUMP 95% IN CALIFORNIA🤩🤩🤩🤩🤩🤩🤩🤩
# 9           9                            💙 BIDE‎N FO‍R RACISM! 💙
#
#    Direct Harassment  Hate Speech  Sexual Harassment  Trolling  Others  Toxic  \
# 0                NaN          1.0                NaN       NaN     NaN    NaN
# 1                NaN          NaN                NaN       NaN     NaN    NaN
# 2                NaN          NaN                NaN       NaN     NaN    NaN
# 3                NaN          1.0                NaN       NaN     NaN    NaN
# 4                NaN          NaN                NaN       NaN     NaN    NaN
# 5                NaN          NaN                NaN       NaN     NaN    NaN
# 6                NaN          NaN                NaN       NaN     NaN    NaN
# 7                NaN          NaN                NaN       NaN     NaN    NaN
# 8                NaN          NaN                NaN       NaN     NaN    NaN
# 9                1.0          1.0                NaN       NaN     NaN    1.0
#
#                                                  POS  \
# 0  [(DEMOCRATS, NNPS), (ARE, VBP), (TERRORISTS!, ...
# 1  [(Let's, NNP), (be, VB), (honest,, VBN), (they...
# 2  [(Where, WRB), (would, MD), (we, PRP), (be, VB...
# 3  [(THEY, NNP), (WON'T, NNP), (BE, NNP), (HAPPY,...
# 4                          [(TRUMP, NN), (2020, CD)]
# 5            [(SALT, NNP), (MUST, NNP), (FLOW, NNP)]
# 6  [(Corn, JJ), (Pop, NNP), (say, VBP), (I, PRP),...
# 7  [(RSBN, NNP), (IS, VBZ), (THE, NNP), (GREATEST...
# 8  [(TRUMP, $), (95%, CD), (IN, NNP), (CALIFORNIA...
# 9  [(💙, JJ), (BIDE‎N, NNP), (FO‍R, NNP), (RACISM!...
#
#                                            tagCounts
# 0                    {'NNPS': 1, 'VBP': 1, 'NNP': 1}
# 1  {'NNP': 4, 'VB': 2, 'VBN': 1, 'PRP': 2, 'VBP':...
# 2  {'WRB': 1, 'MD': 1, 'PRP': 1, 'VB': 1, 'IN': 2...
# 3                                         {'NNP': 9}
# 4                                 {'NN': 1, 'CD': 1}
# 5                                         {'NNP': 3}
# 6  {'JJ': 2, 'NNP': 3, 'VBP': 2, 'PRP': 1, 'NN': ...
# 7                              {'NNP': 11, 'VBZ': 1}
# 8                        {'$': 1, 'CD': 1, 'NNP': 2}
# 9                       {'JJ': 1, 'NNP': 3, 'NN': 1}

# %% [markdown]
# ##### DH POS Tag Count

# %%
dh = df.loc[df['Direct Harassment'] == 1.0]
dh.head()
# Out:
#     Unnamed: 0                                            message  \
# 9            9                            💙 BIDE‎N FO‍R RACISM! 💙
# 10          10  OE BIDEN IS A TROJAN HORSE FOR SOCIALISM THRU ...
# 11          11  The Porn Industry is censoring and taking down...
# 36          36  Biden needs more Adrenochrome Supply to rememb...
# 37          37  A VOTE FOR BIDEN IS A VOTE FOR THE COMMUNIST C...
#
#     Direct Harassment  Hate Speech  Sexual Harassment  Trolling  Others  \
# 9                 1.0          1.0                NaN       NaN     NaN
# 10                1.0          1.0                NaN       NaN     NaN
# 11                1.0          NaN                1.0       NaN     NaN
# 36                1.0          NaN                NaN       NaN     NaN
# 37                1.0          1.0                NaN       NaN     NaN
#
#     Toxic                                                POS  \
# 9     1.0  [(💙, JJ), (BIDE‎N, NNP), (FO‍R, NNP), (RACISM!...
# 10    1.0  [(OE, NNP), (BIDEN, NNP), (IS, VBZ), (A, NNP),...
# 11    1.0  [(The, DT), (Porn, NNP), (Industry, NNP), (is,...
# 36    NaN  [(Biden, NNP), (needs, VBZ), (more, RBR), (Adr...
# 37    NaN  [(A, DT), (VOTE, NNP), (FOR, NNP), (BIDEN, NNP...
#
#                                             tagCounts
# 9                        {'JJ': 1, 'NNP': 3, 'NN': 1}
# 10  {'NNP': 21, 'VBZ': 1, 'CC': 1, ':': 1, 'NN': 2...
# 11  {'DT': 2, 'NNP': 4, 'VBZ': 1, 'VBG': 2, 'CC': ...
# 36  {'NNP': 3, 'VBZ': 1, 'RBR': 1, 'TO': 1, 'VB': ...
# 37             {'DT': 1, 'NNP': 8, 'VBZ': 1, 'IN': 1}

# %%
tag_set = list(set([tag for tags in dh['tagCounts'] for tag in tags]))
for tag in tag_set:
    dh[tag] = dh['tagCounts'].map(lambda x: x.get(tag, 0))
title = 'Frequency of POS Tags in Direct Harassment'    
dh[tag_set].sum().sort_values().plot(kind='barh', logx=True, figsize=(12,8), title=title)
# Out:
# <ipython-input-13-dc25a0686c57>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dh[tag] = dh['tagCounts'].map(lambda x: x.get(tag, 0))
# <AxesSubplot:title={'center':'Frequency of POS Tags in Direct Harassment'}>

# %% [markdown]
# ##### HS POS Tag Count

# %%
hs = df.loc[df['Hate Speech'] == 1.0]
hs.head()
# Out:
#     Unnamed: 0                                            message  \
# 0            0                          DEMOCRATS ARE TERRORISTS!
# 3            3    THEY WON'T BE HAPPY WHEN THEY ARE REGULATED 😛😛😥
# 9            9                            💙 BIDE‎N FO‍R RACISM! 💙
# 10          10  OE BIDEN IS A TROJAN HORSE FOR SOCIALISM THRU ...
# 29          29                   No SOCIALISM on TRUMP'S Watch!!!
#
#     Direct Harassment  Hate Speech  Sexual Harassment  Trolling  Others  \
# 0                 NaN          1.0                NaN       NaN     NaN
# 3                 NaN          1.0                NaN       NaN     NaN
# 9                 1.0          1.0                NaN       NaN     NaN
# 10                1.0          1.0                NaN       NaN     NaN
# 29                NaN          1.0                NaN       NaN     NaN
#
#     Toxic                                                POS  \
# 0     NaN  [(DEMOCRATS, NNPS), (ARE, VBP), (TERRORISTS!, ...
# 3     NaN  [(THEY, NNP), (WON'T, NNP), (BE, NNP), (HAPPY,...
# 9     1.0  [(💙, JJ), (BIDE‎N, NNP), (FO‍R, NNP), (RACISM!...
# 10    1.0  [(OE, NNP), (BIDEN, NNP), (IS, VBZ), (A, NNP),...
# 29    NaN  [(No, DT), (SOCIALISM, NNP), (on, IN), (TRUMP'...
#
#                                             tagCounts
# 0                     {'NNPS': 1, 'VBP': 1, 'NNP': 1}
# 3                                          {'NNP': 9}
# 9                        {'JJ': 1, 'NNP': 3, 'NN': 1}
# 10  {'NNP': 21, 'VBZ': 1, 'CC': 1, ':': 1, 'NN': 2...
# 29                       {'DT': 1, 'NNP': 3, 'IN': 1}

# %%
tag_set = list(set([tag for tags in hs['tagCounts'] for tag in tags]))
for tag in tag_set:
    hs[tag] = hs['tagCounts'].map(lambda x: x.get(tag, 0))
title = 'Frequency of POS Tags in Hate Speech'    
hs[tag_set].sum().sort_values().plot(kind='barh', logx=True, figsize=(12,8), title=title)
# Out:
# <ipython-input-15-e3245e77955c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs[tag] = hs['tagCounts'].map(lambda x: x.get(tag, 0))
# <AxesSubplot:title={'center':'Frequency of POS Tags in Direct Harassment'}>

# %% [markdown]
# ##### SH POS Tag Count

# %%
sh = df.loc[df['Sexual Harassment'] == 1.0]
sh.head()
# Out:
#       Unnamed: 0                                            message  \
# 11            11  The Porn Industry is censoring and taking down...
# 94            94                        obama bangs bidens butthole
# 3122        3122                           â¤ï¸hairy legged women
# 3642        3642                                        Lady gag me
# 3726        3726        Lady gaga is no lady and she is over rated1
#
#       Direct Harassment  Hate Speech  Sexual Harassment  Trolling  Others  \
# 11                  1.0          NaN                1.0       NaN     NaN
# 94                  1.0          NaN                1.0       1.0     NaN
# 3122                NaN          NaN                1.0       NaN     NaN
# 3642                NaN          NaN                1.0       NaN     NaN
# 3726                NaN          NaN                1.0       NaN     NaN
#
#       Toxic                                                POS  \
# 11      1.0  [(The, DT), (Porn, NNP), (Industry, NNP), (is,...
# 94      1.0  [(obama, JJ), (bangs, NNS), (bidens, NNS), (bu...
# 3122    NaN  [(â¤ï¸hairy, NNS), (legged, VBD), (women, NNS)]
# 3642    NaN               [(Lady, NNP), (gag, VBZ), (me, PRP)]
# 3726    1.0  [(Lady, JJ), (gaga, NN), (is, VBZ), (no, DT), ...
#
#                                               tagCounts
# 11    {'DT': 2, 'NNP': 4, 'VBZ': 1, 'VBG': 2, 'CC': ...
# 94                        {'JJ': 1, 'NNS': 2, 'VBP': 1}
# 3122                               {'NNS': 2, 'VBD': 1}
# 3642                     {'NNP': 1, 'VBZ': 1, 'PRP': 1}
# 3726  {'JJ': 1, 'NN': 3, 'VBZ': 2, 'DT': 1, 'CC': 1,...

# %%
tag_set = list(set([tag for tags in sh['tagCounts'] for tag in tags]))
for tag in tag_set:
    sh[tag] = sh['tagCounts'].map(lambda x: x.get(tag, 0))
title = 'Frequency of POS Tags in Sexual Harassment'    
sh[tag_set].sum().sort_values().plot(kind='barh', logx=True, figsize=(12,8), title=title)
# Out:
# <ipython-input-17-05ecbd64675f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sh[tag] = sh['tagCounts'].map(lambda x: x.get(tag, 0))
# <AxesSubplot:title={'center':'Frequency of POS Tags in Direct Harassment'}>

# %% [markdown]
# ##### Trolling POS Tag Count

# %%
t = df.loc[df['Trolling'] == 1.0]
t.head()
# Out:
#     Unnamed: 0                                            message  \
# 25          25          Avoid all MSM - it's all lies and disinfo
# 32          32           We just need to let Byedone be bye done!
# 34          34                          HUNTER & BIGFOOT SPOTTED🚨
# 41          41  📢📢📢BREAKING NEWS : BIDEN CAUGHT LYING! AGAIN! 📢📢📢
# 57          57  Hunter Biden's laptop has compromised JOE BIDE...
#
#     Direct Harassment  Hate Speech  Sexual Harassment  Trolling  Others  \
# 25                NaN          NaN                NaN       1.0     NaN
# 32                NaN          NaN                NaN       1.0     NaN
# 34                NaN          NaN                NaN       1.0     NaN
# 41                NaN          NaN                NaN       1.0     NaN
# 57                NaN          NaN                NaN       1.0     NaN
#
#     Toxic                                                POS  \
# 25    NaN  [(Avoid, NNP), (all, DT), (MSM, NNP), (-, :), ...
# 32    NaN  [(We, PRP), (just, RB), (need, VBP), (to, TO),...
# 34    NaN  [(HUNTER, NNP), (&, CC), (BIGFOOT, NNP), (SPOT...
# 41    NaN  [(📢📢📢BREAKING, JJ), (NEWS, NN), (:, :), (BIDEN...
# 57    NaN  [(Hunter, NNP), (Biden's, NNP), (laptop, NN), ...
#
#                                             tagCounts
# 25  {'NNP': 2, 'DT': 2, ':': 1, 'NN': 2, 'NNS': 1,...
# 32  {'PRP': 1, 'RB': 1, 'VBP': 1, 'TO': 1, 'VB': 2...
# 34                                {'NNP': 3, 'CC': 1}
# 41               {'JJ': 1, 'NN': 2, ':': 1, 'NNP': 4}
# 57  {'NNP': 9, 'NN': 1, 'VBZ': 2, 'VBN': 1, 'PRP':...

# %%
tag_set = list(set([tag for tags in t['tagCounts'] for tag in tags]))
for tag in tag_set:
    t[tag] = t['tagCounts'].map(lambda x: x.get(tag, 0))
title = 'Frequency of POS Tags in Trolling'    
t[tag_set].sum().sort_values().plot(kind='barh', logx=True, figsize=(12,8), title=title)
# Out:
# <ipython-input-19-21e13f24212d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t[tag] = t['tagCounts'].map(lambda x: x.get(tag, 0))
# <AxesSubplot:title={'center':'Frequency of POS Tags in Direct Harassment'}>

# %% [markdown]
# ##### Others POS Tag Count

# %%
o = df.loc[df['Others'] == 1.0]
o.head()
# Out:
#       Unnamed: 0                                            message  \
# 2097        2097                CHINA JOE FOR ELECTRIC CHAIR 2020!!
# 2266        2266  Of Biden wins we should burn the towns that vo...
# 2277        2277                                  Bang your Head !!
# 5923        5923                    Baby Murderers for Biden/Harris
# 6710        6710                    don't mess with me! i have bars
#
#       Direct Harassment  Hate Speech  Sexual Harassment  Trolling  Others  \
# 2097                NaN          NaN                NaN       NaN     1.0
# 2266                NaN          NaN                NaN       NaN     1.0
# 2277                NaN          NaN                NaN       NaN     1.0
# 5923                NaN          1.0                NaN       NaN     1.0
# 6710                NaN          NaN                NaN       NaN     1.0
#
#       Toxic                                                POS  \
# 2097    NaN  [(CHINA, NNP), (JOE, NNP), (FOR, NNP), (ELECTR...
# 2266    1.0  [(Of, IN), (Biden, NNP), (wins, VBZ), (we, PRP...
# 2277    NaN  [(Bang, NNP), (your, PRP$), (Head, NNP), (!!, ...
# 5923    1.0  [(Baby, NNP), (Murderers, NNP), (for, IN), (Bi...
# 6710    NaN  [(don't, NN), (mess, NN), (with, IN), (me!, NN...
#
#                                               tagCounts
# 2097                                {'NNP': 5, 'CD': 1}
# 2266  {'IN': 2, 'NNP': 1, 'VBZ': 1, 'PRP': 2, 'MD': ...
# 2277                     {'NNP': 2, 'PRP$': 1, 'NN': 1}
# 5923                                {'NNP': 3, 'IN': 1}
# 6710             {'NN': 3, 'IN': 1, 'NNS': 2, 'VBP': 1}

# %%
tag_set = list(set([tag for tags in o['tagCounts'] for tag in tags]))
for tag in tag_set:
    o[tag] = o['tagCounts'].map(lambda x: x.get(tag, 0))
title = 'Frequency of POS Tags in Others'    
o[tag_set].sum().sort_values().plot(kind='barh', logx=True, figsize=(12,8), title=title)
# Out:
# <ipython-input-21-91b224105b50>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o[tag] = o['tagCounts'].map(lambda x: x.get(tag, 0))
# <AxesSubplot:title={'center':'Frequency of POS Tags in Others'}>

# %% [markdown]
# ##### Toxic POS Tag Counts

# %%
tox = df.loc[df['Toxic'] == 1.0]
tox.head()
# Out:
#      Unnamed: 0                                            message  \
# 9             9                            💙 BIDE‎N FO‍R RACISM! 💙
# 10           10  OE BIDEN IS A TROJAN HORSE FOR SOCIALISM THRU ...
# 11           11  The Porn Industry is censoring and taking down...
# 94           94                        obama bangs bidens butthole
# 187         187                                            BLM = 💩
#
#      Direct Harassment  Hate Speech  Sexual Harassment  Trolling  Others  \
# 9                  1.0          1.0                NaN       NaN     NaN
# 10                 1.0          1.0                NaN       NaN     NaN
# 11                 1.0          NaN                1.0       NaN     NaN
# 94                 1.0          NaN                1.0       1.0     NaN
# 187                NaN          1.0                NaN       1.0     NaN
#
#      Toxic                                                POS  \
# 9      1.0  [(💙, JJ), (BIDE‎N, NNP), (FO‍R, NNP), (RACISM!...
# 10     1.0  [(OE, NNP), (BIDEN, NNP), (IS, VBZ), (A, NNP),...
# 11     1.0  [(The, DT), (Porn, NNP), (Industry, NNP), (is,...
# 94     1.0  [(obama, JJ), (bangs, NNS), (bidens, NNS), (bu...
# 187    1.0                    [(BLM, NNP), (=, NNP), (💩, NN)]
#
#                                              tagCounts
# 9                         {'JJ': 1, 'NNP': 3, 'NN': 1}
# 10   {'NNP': 21, 'VBZ': 1, 'CC': 1, ':': 1, 'NN': 2...
# 11   {'DT': 2, 'NNP': 4, 'VBZ': 1, 'VBG': 2, 'CC': ...
# 94                       {'JJ': 1, 'NNS': 2, 'VBP': 1}
# 187                                {'NNP': 2, 'NN': 1}

# %%
tag_set = list(set([tag for tags in tox['tagCounts'] for tag in tags]))
for tag in tag_set:
    tox[tag] = tox['tagCounts'].map(lambda x: x.get(tag, 0))
title = 'Frequency of POS Tags in Others'    
tox[tag_set].sum().sort_values().plot(kind='barh', logx=True, figsize=(12,8), title=title)
# Out:
# <ipython-input-23-43978014844a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tox[tag] = tox['tagCounts'].map(lambda x: x.get(tag, 0))
# <AxesSubplot:title={'center':'Frequency of POS Tags in Others'}>
