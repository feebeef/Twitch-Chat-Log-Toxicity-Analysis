# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import base64
import random
from operator import itemgetter
import json

# %% [markdown]
# ### Split Files

# %%
fileFormat = "_cleanedAnon"
file = "rae" # <----- CHANGE VALUE PER FILE
fileName = file+fileFormat 
numOfFiles = 2 # <----- CHANGE VALUE PER FILE
numSplit = 2237 # <----- CHANGE VALUE PER FILE
temp = numSplit

df = pd.read_csv(fileName + ".csv")
df.head(10)
# Out:
#    Unnamed: 0 time_text                                            message  \
# 0           0      0:02                                      yeeeeeeeeeeee
# 1           1      0:09                                           Let’s go
# 2           2      0:10                                            !member
# 3           3      0:13                                             Yeeeee
# 4           4      0:14                                          :_raeWoo:
# 5           5      0:14                       thanks [username@nunnAnAnLg]
# 6           6      0:16                     :_raeHype::_raeHype::_raeHype:
# 7           7      0:17   probably not the best tutorial since all of t...
# 8           8      0:19                        [username@nunnAnAnLg] boted
# 9           9      0:20                                         no feather
#
#                 author  Direct Harassment  Hate Speech  Sexual Harassment  \
# 0  username@leayeaaCay                NaN          NaN                NaN
# 1  username@xxepyyyyyx                NaN          NaN                NaN
# 2  username@aidCiih Ci                NaN          NaN                NaN
# 3  username@xxepyyyyyx                NaN          NaN                NaN
# 4  username@mbJhbabmhi                NaN          NaN                NaN
# 5  username@niMjrrMirK                NaN          NaN                NaN
# 6  username@iKoo l kye                NaN          NaN                NaN
# 7  username@rvGataGvaa                NaN          NaN                NaN
# 8  username@eyecacaJae                NaN          NaN                NaN
# 9  username@A eAdAwAee                NaN          NaN                NaN
#
#    Trolling  Others  Toxic
# 0       NaN     NaN    NaN
# 1       NaN     NaN    NaN
# 2       NaN     NaN    NaN
# 3       NaN     NaN    NaN
# 4       NaN     NaN    NaN
# 5       NaN     NaN    NaN
# 6       NaN     NaN    NaN
# 7       NaN     NaN    NaN
# 8       NaN     NaN    NaN
# 9       NaN     NaN    NaN

# %%
for i in range(numOfFiles-1):
    if i == 0:
        x=i
        df_1 = df.iloc[:numSplit,:]
        #df_1 = df.iloc[6000:6000+numSplit,:]
        #df_1.drop(df.columns[0], axis=1)
        outputFormat = "_"+str(i)+".csv"
        df_1.to_csv(file + outputFormat, index=False)
        #numSplit = numSplit +1
    else:
        x=i
        df_1 = df.iloc[numSplit:numSplit+temp,:]
        #df_1.drop(df.columns[0], axis=1)
        numSplit = numSplit+temp
        outputFormat = "_"+str(i)+".csv"
        df_1.to_csv(file + outputFormat, index=False)
        #numSplit+=1
    
df_2 = df.iloc[numSplit:,:]
#df_2 = df.iloc[6000+numSplit:,:]
#df_2.drop(df.columns[0], axis=1)
x+=1
outputFormat = "_"+str(x)+".csv"
df_2.to_csv(file + outputFormat, index=False)
#df_1 = df.iloc[:numSplit+1,:]
#df_2 = df.iloc[numSplit+2:,:]
