# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import base64
import random
from operator import itemgetter
import json

# %% [markdown]
# ### Split Files

# %%
fileFormat = "_cleanedAnon"
file = "pew0" # <----- CHANGE VALUE PER FILE
fileName = file+fileFormat 
numOfFiles = 2 # <----- CHANGE VALUE PER FILE
numSplit = 3000 # <----- CHANGE VALUE PER FILE
temp = numSplit

df = pd.read_csv(fileName + ".csv")
df.head(10)
# Out:
#    Unnamed: 0                                            message  \
# 0           0                                              ayyyy
# 1           1  :_pewdieDuck::_pewdieDuck::_pewdieDuck::_pewdi...
# 2           2                                   :_pewdieRicardo:
# 3           3   :_pewdieBrofist::_pewdieBrofist::_pewdieBrofist:
# 4           4                                          Late gang
# 5           5                               corpse :_pewdieSIMP:
# 6           6  Yess phasmophobia with corpse could be awesome !!
# 7           7  if you were turned into an animal, what would ...
# 8           8                                   :_pewdieBrofist:
# 9           9                             phasmophobia vr is pog
#
#                 author time_text  Direct Harassment  Hate Speech  \
# 0  username@HtHrtytytr     -0:00                NaN          NaN
# 1  username@ei.lteiiik      0:01                NaN          NaN
# ...

# %%
for i in range(numOfFiles-1):
    if i == 0:
        x=i
        df_1 = df.iloc[:numSplit,:]
        #df_1 = df.iloc[6000:6000+numSplit,:]
        #df_1.drop(df.columns[0], axis=1)
        outputFormat = "_"+str(i)+".csv"
        df_1.to_csv(file + outputFormat, index=False)
        #numSplit = numSplit +1
    else:
        x=i
        df_1 = df.iloc[numSplit:numSplit+temp,:]
        #df_1.drop(df.columns[0], axis=1)
        numSplit = numSplit+temp
        outputFormat = "_"+str(i)+".csv"
        df_1.to_csv(file + outputFormat, index=False)
        #numSplit+=1
    
df_2 = df.iloc[numSplit:,:]
#df_2 = df.iloc[6000+numSplit:,:]
#df_2.drop(df.columns[0], axis=1)
x+=1
outputFormat = "_"+str(x)+".csv"
df_2.to_csv(file + outputFormat, index=False)
#df_1 = df.iloc[:numSplit+1,:]
#df_2 = df.iloc[numSplit+2:,:]
